# %%
import numpy as np
import time
import ipywidgets as widgets
from matplotlib import pyplot as plt
import matplotlib.animation as animation 
from ipywidgets import interact, Button
from IPython.display import display
import threading
import argparse

# %%
fig, ax = plt.subplots(figsize=(15, 10))
ax.set_xlim([0, 100])
ax.set_ylim([0, 100])
ax.set_xlabel('Time')
ax.set_ylabel('Forest')
ax.grid()
plt.xticks(np.arange(0, 101, 4.0))
plt.yticks(np.arange(0, 101, 4.0))
plt.show()

# %%
trees = np.random.randint(2, size=(25,25))
img.set_data(trees) 
img = ax.imshow(trees, interpolation='nearest') 
ani = animation.FuncAnimation( fig, f, fargs = ( img, trees, 50 ),
                               frames = 10, interval = 50 )
if args.movfile: 
        ani.save(args.movfile, fps=30, extra_args=['-vcodec', 'libx264']) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-d0499ebe018a> in <module>
#       4 ani = animation.FuncAnimation( fig, f, fargs = ( img, trees, 50 ),
#       5                                frames = 10, interval = 50 )
# ----> 6 if args.movfile:
#       7         ani.save(args.movfile, fps=30, extra_args=['-vcodec', 'libx264'])
#       8 plt.show()
#
# NameError: name 'args' is not defined

# %%
def f():
    return()
